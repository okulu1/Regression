# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
df= pd.read_csv('energydata_complete.csv')

df=df.drop(['date','lights'],axis=1)
df.head()
# Out:
#    Appliances     T1       RH_1    T2       RH_2     T3       RH_3         T4  \
# 0          60  19.89  47.596667  19.2  44.790000  19.79  44.730000  19.000000
# 1          60  19.89  46.693333  19.2  44.722500  19.79  44.790000  19.000000
# 2          50  19.89  46.300000  19.2  44.626667  19.79  44.933333  18.926667
# 3          50  19.89  46.066667  19.2  44.590000  19.79  45.000000  18.890000
# 4          60  19.89  46.333333  19.2  44.530000  19.79  45.000000  18.890000
#
#         RH_4         T5  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  45.566667  17.166667  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  45.992500  17.166667  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  45.890000  17.166667  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  45.723333  17.166667  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  45.530000  17.200000  ...  17.000000  45.40  6.133333        733.9    92.0
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
reg_min = MinMaxScaler()
normalized_df = pd.DataFrame(reg_min.fit_transform(df),columns=df.columns)
normalized_df
# Out:
#        Appliances        T1      RH_1        T2      RH_2        T3      RH_3  \
# 0        0.046729  0.327350  0.566187  0.225345  0.684038  0.215188  0.746066
# 1        0.046729  0.327350  0.541326  0.225345  0.682140  0.215188  0.748871
# 2        0.037383  0.327350  0.530502  0.225345  0.679445  0.215188  0.755569
# 3        0.037383  0.327350  0.524080  0.225345  0.678414  0.215188  0.758685
# 4        0.046729  0.327350  0.531419  0.225345  0.676727  0.215188  0.758685
# ...           ...       ...       ...       ...       ...       ...       ...
# 19730    0.084112  0.926786  0.537657  0.711655  0.606309  0.830841  0.579374
# 19731    0.074766  0.919747  0.536006  0.701769  0.607836  0.825302  0.582178
# 19732    0.242991  0.919747  0.538666  0.692651  0.627198  0.818378  0.603988
# 19733    0.383178  0.919747  0.549491  0.677054  0.634717  0.805085  0.585294
# 19734    0.392523  0.919747  0.538758  0.666171  0.632902  0.799546  0.579062
#
# ...

# %%
target1 = normalized_df['Appliances']
features= normalized_df.drop(['Appliances'],axis=1)
features
# Out:
#              T1      RH_1        T2      RH_2        T3      RH_3        T4  \
# 0      0.327350  0.566187  0.225345  0.684038  0.215188  0.746066  0.351351
# 1      0.327350  0.541326  0.225345  0.682140  0.215188  0.748871  0.351351
# 2      0.327350  0.530502  0.225345  0.679445  0.215188  0.755569  0.344745
# 3      0.327350  0.524080  0.225345  0.678414  0.215188  0.758685  0.341441
# 4      0.327350  0.531419  0.225345  0.676727  0.215188  0.758685  0.341441
# ...         ...       ...       ...       ...       ...       ...       ...
# 19730  0.926786  0.537657  0.711655  0.606309  0.830841  0.579374  0.864865
# 19731  0.919747  0.536006  0.701769  0.607836  0.825302  0.582178  0.864865
# 19732  0.919747  0.538666  0.692651  0.627198  0.818378  0.603988  0.864865
# 19733  0.919747  0.549491  0.677054  0.634717  0.805085  0.585294  0.864865
# 19734  0.919747  0.538758  0.666171  0.632902  0.799546  0.579062  0.864865
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features,target1,
test_size=0.3, random_state=42)

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_hat = linear_model.predict(x_test)
y_hat
# Out:
# array([0.03322207, 0.24411599, 0.03400024, ..., 0.06844707, 0.10032325,
#        0.05722198])

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_hat)
round(mae, 2)
# Out:
# 0.05

# %%
import numpy as np
rss = np.sum(np.square(y_test - y_hat))
round(rss, 2)
# Out:
# 45.35

# %%
#Root Mean Square Error (RMSE)
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, y_hat))
round(rmse, 3)
# Out:
# 0.088

# %%
weights=np.array([linear_model.coef_]).reshape(26,1)


np.max(weights)
# Out:
# 0.5535465998386391

# %%
np.min(weights)
# Out:
# -0.4566979483385004

# %%
feature_name=np.array([features.columns]).reshape(26,1)
feature_name
# Out:
# array([['T1'],
#        ['RH_1'],
#        ['T2'],
#        ['RH_2'],
#        ['T3'],
#        ['RH_3'],
#        ['T4'],
#        ['RH_4'],
#        ['T5'],
#        ['RH_5'],
#        ['T6'],
#        ['RH_6'],
#        ['T7'],
#        ['RH_7'],
#        ['T8'],
#        ['RH_8'],
#        ['T9'],
#        ['RH_9'],
#        ['T_out'],
#        ['Press_mm_hg'],
#        ['RH_out'],
#        ['Windspeed'],
#        ['Visibility'],
#        ['Tdewpoint'],
#        ['rv1'],
#        ['rv2']], dtype=object)

# %%
linear_reg_weights= np.hstack((feature_name,weights))

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0.4)
ridge_reg.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.4)

# %%
ridge_predict=ridge_reg.predict(x_test)

# %%
#Root Mean Square Error (RMSE)
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test,ridge_predict))
round(rmse, 3)
# Out:
# 0.088

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.001)

# %%
lasso_weights=np.array([lasso_reg.coef_]).reshape(26,1)
lasso_weights.shape
# Out:
# (26, 1)

# %%
lasso_features=np.array([features.columns]).reshape(26,1)
feature_name
# Out:
# array([['T1'],
#        ['RH_1'],
#        ['T2'],
#        ['RH_2'],
#        ['T3'],
#        ['RH_3'],
#        ['T4'],
#        ['RH_4'],
#        ['T5'],
#        ['RH_5'],
#        ['T6'],
#        ['RH_6'],
#        ['T7'],
#        ['RH_7'],
#        ['T8'],
#        ['RH_8'],
#        ['T9'],
#        ['RH_9'],
#        ['T_out'],
#        ['Press_mm_hg'],
#        ['RH_out'],
#        ['Windspeed'],
#        ['Visibility'],
#        ['Tdewpoint'],
#        ['rv1'],
#        ['rv2']], dtype=object)

# %%
lasso_weight= np.hstack((feature_name,lasso_weights))
lasso_weight
# Out:
# array([['T2', 0.0],
#        ['RH_2', -0.0],
#        ['T3', 0.0],
#        ['RH_3', 0.0],
#        ['T4', -0.0],
#        ['RH_4', 0.0],
#        ['T5', -0.0],
#        ['RH_5', 0.0],
#        ['T6', 0.0],
#        ['RH_6', -0.0],
#        ['T7', -0.0],
#        ['RH_7', -0.0],
#        ['T8', 0.0],
#        ['RH_8', -0.00011003649473682741],
#        ['T9', -0.0],
#        ['RH_9', -0.0],
#        ['T_out', 0.0],
#        ['Press_mm_hg', -0.0],
#        ['RH_out', -0.04955749437854849],
#        ['Windspeed', 0.002911764791178164],
#        ['Visibility', 0.0],
#        ['Tdewpoint', 0.0],
#        ['rv1', -0.0],
#        ['rv2', -0.0]], dtype=object)

# %%
lasso_predict=lasso_reg.predict(x_test)

# %%
#Root Mean Square Error (RMSE)
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test,lasso_predict))
round(rmse, 3)
# Out:
# 0.094

# %%
R_square=linear_model.score(x_train,y_train)
round(R_square,2)
# Out:
# 0.14

# %%
input1 = df[['T2']]
output = df[['T6']]

# %%
linear_model1 = LinearRegression()

# %%
linear_model1.fit(input1,output)
# Out:
# LinearRegression()

# %%
linear_model1.score(input1,output)
# Out:
# 0.6418990830855493
